# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import datetime as dt

# %%
df_clean = pd.read_csv('/home/kevin/Documents/projets/Dev IA/cinema_prediction/movies_clean_v1.csv')
# Je retransforme la colonne date en datetime au cas ou
df_clean['date'] = pd.to_datetime(df_clean['date'])

# Je catégorise en saisons
def map_season(month):
    if month in [3, 4, 5]:  # Printemps (mars, avril, mai)
        return 'Printemps'
    elif month in [6, 7, 8]:  # Été (juin, juillet, août)
        return 'Été'
    elif month in [9, 10, 11]:  # Automne (septembre, octobre, novembre)
        return 'Automne'
    else:  # Hiver (décembre, janvier, février)
        return 'Hiver'

# J'applique le mapping
df_clean['season'] = df_clean['date'].dt.month.apply(map_season)

df_clean.head(3)

# Je retransforme la colonne date en datetime au cas ou
df_clean['date'] = pd.to_datetime(df_clean['date'])

# Je catégorise en saisons
def map_season(month):
    if month in [3, 4, 5]:  # Printemps (mars, avril, mai)
        return 'Printemps'
    elif month in [6, 7, 8]:  # Été (juin, juillet, août)
        return 'Été'
    elif month in [9, 10, 11]:  # Automne (septembre, octobre, novembre)
        return 'Automne'
    else:  # Hiver (décembre, janvier, février)
        return 'Hiver'

# J'applique le mapping
df_clean['season'] = df_clean['date'].dt.month.apply(map_season)

def categorisation_studio (stud):
    big = ['Walt Disney Pictures','Warner Bros.','Paramount','Sony Pictures','Universal','20th Century Fox','Lionsgate','Columbia']
    medium = ['Pathé','Studiocanal','Gaumont','UGC Distribution','SND','Le Pacte',' Metropolitan','EuropaCorp','GBVI',' Wild Bunch','UFD','ARP Selection','Ad vitam','Haut et Court',' Films du Losange','Rezo Films','TFM Distribution']
    small = ['Gébéka','Memento Films','KMBO','Océan Films','AMLF','MK2 Diffusion','Gaumont Sony','Apollo Films','Sophie Dulac','Eurozoom','Jour2Fête','Pan-Européenne','Cinema Public','Polygram']

    if stud in big:
        return 3
    elif stud in medium:
        return 2
    elif stud in small:
        return 1
    else:
        return 0
    
df_clean['coeff_studio'] = df_clean['studio'].apply(categorisation_studio)
df_clean.head(3)
# Out:
#                                              acteurs     budget  \
# 0                  Sam Worthington, Sigourney Weaver  315000000
# 1  Daniel Radcliffe, Emma Watson, Gary Oldman, Al...  130000000
# 2  Adam Driver, Benicio Del Toro, Joseph Gordon-L...  200000000
#
#      compositeur       date  entrees_premiere_semaine  franchise  \
# 0   James Horner 2009-12-16                   2648596  Franchise
# 1  John Williams 2004-06-02                   2503699  Franchise
# 2  John Williams 2017-12-13                   2510462  Franchise
#
#              genre        pays        producteur     realisateur remake  \
# 0  Science Fiction  Etats-Unis               NaN   James Cameron    NaN
# 1          Fantasy  Etats-Unis               NaN  Alfonso Cuaron    NaN
# 2          Fantasy  Etats-Unis  Kathleen Kennedy    Rian Johnson    NaN
#
#                  studio                                    titre season  \
# 0      20th Century Fox                                   Avatar  Hiver
# 1          Warner Bros.  Harry Potter et le prisonnier d'Azkaban    Été
# 2  Walt Disney Pictures             Star Wars: Les derniers Jedi  Hiver
#
#    coeff_studio
# 0             3
# 1             3
# 2             3

# %%
df_clean['coeff_studio'].unique()
# Out:
# array([3, 0, 2, 1])

# %%
df_clean
# Out:
#                                                 acteurs     budget  \
# 0                     Sam Worthington, Sigourney Weaver  315000000
# 1     Daniel Radcliffe, Emma Watson, Gary Oldman, Al...  130000000
# 2     Adam Driver, Benicio Del Toro, Joseph Gordon-L...  200000000
# 3     Chris Evans, Chris Hemsworth, Josh Brolin, Rob...  295000000
# 4       Sam Worthington, Sigourney Weaver, Kate Winslet  350000000
# ...                                                 ...        ...
# 4536                                      Jason Statham   40000000
# 4537                       Alan Rickman, Dustin Hoffman   49515804
# 4538  Dany Boon, François Berléand, Valérie Bonneton...   27800000
# 4539                      Emmanuelle Devos, Sergi Lopez    2700000
# 4540  Michael Fassbender, Charlotte Gainsbourg, Val ...   35000000
#
#          compositeur       date  entrees_premiere_semaine  franchise  \
# 0       James Horner 2009-12-16                   2648596  Franchise
# 1      John Williams 2004-06-02                   2503699  Franchise
# 2      John Williams 2017-12-13                   2510462  Franchise
# 3     Alan Silvestri 2018-04-25                   2565953  Franchise
# 4                NaN 2022-12-14                   2739848  Franchise
# ...              ...        ...                       ...        ...
# 4536             NaN 2011-04-06                    122671        NaN
# 4537             NaN 2006-10-04                    305743        NaN
# 4538             NaN 2018-02-28                   2429906        NaN
# 4539             NaN 2020-07-01                    121018        NaN
# 4540             NaN 2017-11-29                    121112        NaN
#
#                   genre             pays        producteur       realisateur  \
# 0       Science Fiction       Etats-Unis               NaN     James Cameron
# 1               Fantasy       Etats-Unis               NaN    Alfonso Cuaron
# 2               Fantasy       Etats-Unis  Kathleen Kennedy      Rian Johnson
# 3             Comicbook       Etats-Unis       Kevin Feige  Russo (brothers)
# 4       Science Fiction       Etats-Unis               NaN     James Cameron
# ...                 ...              ...               ...               ...
# 4536  Aventure - Action       Etats-Unis               NaN        Simon West
# 4537              Drame        Allemagne               NaN               NaN
# 4538            Comédie           France               NaN         Dany Boon
# 4539            Comédie           France               NaN               NaN
# 4540           Thriller  Grande-Bretagne               NaN               NaN
#
#       remake                studio                                    titre  \
# 0        NaN      20th Century Fox                                   Avatar
# 1        NaN          Warner Bros.  Harry Potter et le prisonnier d'Azkaban
# 2        NaN  Walt Disney Pictures             Star Wars: Les derniers Jedi
# 3        NaN  Walt Disney Pictures                   Avengers: Infinity War
# 4        NaN  Walt Disney Pictures                Avatar : la voie de l'eau
# ...      ...                   ...                                      ...
# 4536  Remake          Metropolitan                      Le Flingueur (2011)
# 4537     NaN          Metropolitan      Le Parfum : histoire d'un meurtrier
# 4538     NaN                 Pathé                       La Ch’tite famille
# 4539     NaN              Pyramide                              Les Parfums
# 4540     NaN             Universal                     Le Bonhomme de neige
#
#          season  coeff_studio
# 0         Hiver             3
# 1           Été             3
# 2         Hiver             3
# 3     Printemps             3
# 4         Hiver             3
# ...         ...           ...
# 4536  Printemps             0
# 4537    Automne             0
# 4538      Hiver             2
# 4539        Été             0
# 4540    Automne             3
#
# [4541 rows x 15 columns]

# %%
df_clean.dtypes
# Out:
# acteurs                             object
# budget                               int64
# compositeur                         object
# date                        datetime64[ns]
# entrees_premiere_semaine             int64
# franchise                           object
# genre                               object
# pays                                object
# producteur                          object
# realisateur                         object
# remake                              object
# studio                              object
# titre                               object
# season                              object
# coeff_studio                         int64
# dtype: object

# %%
df_clean.to_csv('movies_clean_v1.csv', index=False)
